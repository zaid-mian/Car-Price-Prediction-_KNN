# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import OneHotEncoder,LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv("cars.csv")
df.head(3)
# Out:
#    Make      Model  Variant Ex-Showroom_Price Displacement  Cylinders  \
# 0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc        2.0
# 1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc        2.0
# 2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
# 1                  2.0  RWD (Rear Wheel Drive)                In-line
# 2                  2.0  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm  ... Leather_Wrapped_Steering Automatic_Headlamps Engine_Type  \
# 0         BS IV  ...                      NaN                 NaN         NaN
# 1         BS IV  ...                      NaN                 NaN         NaN
# 2         BS IV  ...                      NaN                 NaN         NaN
#
#   ASR_/_Traction_Control Cruise_Control USB_Ports Heads-Up_Display  \
# 0                    NaN            NaN       NaN              NaN
# 1                    NaN            NaN       NaN              NaN
# 2                    NaN            NaN       NaN              NaN
#
#   Welcome_Lights  Battery Electric_Range
# 0            NaN      NaN            NaN
# 1            NaN      NaN            NaN
# 2            NaN      NaN            NaN
#
# [3 rows x 140 columns]

# %%
df=df[["Make", "Model", "Variant", "Ex-Showroom_Price", "Displacement", "Cylinders",
       "Valves_Per_Cylinder", "Drivetrain", "Cylinder_Configuration", "Emission_Norm"]]
df.head(3)
# Out:
#    Make      Model  Variant Ex-Showroom_Price Displacement  Cylinders  \
# 0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc        2.0
# 1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc        2.0
# 2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
# 1                  2.0  RWD (Rear Wheel Drive)                In-line
# 2                  2.0  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm
# 0         BS IV
# 1         BS IV
# 2         BS IV

# %%
df["Displacement"] = df["Displacement"].astype(str).str.replace("cc", "").astype(float)
df["Ex-Showroom_Price"] = df["Ex-Showroom_Price"].astype(str).str.replace("Rs.", "", regex=False).str.replace(",", "", regex=False).astype(int)

# %%
y = df["Ex-Showroom_Price"]
x = df.drop("Ex-Showroom_Price", axis=1)

# %%
y
# Out:
# 0        292667
# 1        236447
# 2        296661
# 3        334768
# 4        272223
#          ...
# 1271    1302000
# 1272    1421000
# 1273    1431000
# 1274    1201000
# 1275    6862560
# Name: Ex-Showroom_Price, Length: 1276, dtype: int64

# %%
x
# Out:
#             Make      Model        Variant  Displacement  Cylinders  \
# 0           Tata  Nano Genx             Xt         624.0        2.0
# 1           Tata  Nano Genx             Xe         624.0        2.0
# 2           Tata  Nano Genx        Emax Xm         624.0        2.0
# 3           Tata  Nano Genx            Xta         624.0        2.0
# 4           Tata  Nano Genx             Xm         624.0        2.0
# ...          ...        ...            ...           ...        ...
# 1271       Honda       City   Vx Mt Diesel        1498.0        4.0
# 1272       Honda       City   Zx Mt Diesel        1498.0        4.0
# 1273       Honda       City  Zx Cvt Petrol        1497.0        4.0
# 1274       Honda       City   V Cvt Petrol        1497.0        4.0
# 1275  Mitsubishi    Montero         3.2 At        3200.0        4.0
#
#       Valves_Per_Cylinder               Drivetrain Cylinder_Configuration  \
# 0                     2.0   RWD (Rear Wheel Drive)                In-line
# 1                     2.0   RWD (Rear Wheel Drive)                In-line
# 2                     2.0   RWD (Rear Wheel Drive)                In-line
# 3                     2.0   RWD (Rear Wheel Drive)                In-line
# 4                     2.0   RWD (Rear Wheel Drive)                In-line
# ...                   ...                      ...                    ...
# 1271                  4.0  FWD (Front Wheel Drive)                In-line
# 1272                  4.0  FWD (Front Wheel Drive)                In-line
# 1273                  4.0  FWD (Front Wheel Drive)                In-line
# 1274                  4.0  FWD (Front Wheel Drive)                In-line
# 1275                  4.0    AWD (All Wheel Drive)                In-line
#
#      Emission_Norm
# 0            BS IV
# 1            BS IV
# 2            BS IV
# 3            BS IV
# 4            BS IV
# ...            ...
# 1271         BS IV
# 1272         BS IV
# 1273          BS 6
# 1274          BS 6
# 1275         BS IV
#
# [1276 rows x 9 columns]

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.25)

# %%
categorical_columns = x_train.select_dtypes(include="object").columns.tolist()
numerical_columns = x_train.select_dtypes(include=["int64", "float64"]).columns.tolist()

# %%
numerical_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="mean")),
    ("scaler", StandardScaler())
])

# %%
categorical_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

# %%
preprocessor = ColumnTransformer([
    ("num", numerical_pipeline, numerical_columns),
    ("cat", categorical_pipeline, categorical_columns)
])

# %%
model = KNeighborsRegressor(n_neighbors=5)

# %%
pipe = Pipeline([
    ("preprocessing", preprocessor),
    ("model", model)
])

# %%
pipe.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Displacement', 'Cylinders',
#                                                    'Valves_Per_Cylinder']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['Make', 'Model', 'Variant',
#                                                    'Drivetrain',
#                                                    'Cylinder_Configuration',
#                                                    'Emission_Norm'])])),
#                 ('model', KNeighborsRegressor())])

# %%
p = pipe.predict(x_test)

# %%
mean_squared_error(y_test, p)
# Out:
# 28287770074710.062

# %%
 r2_score(y_test, p)
# Out:
# 0.8366786460257131
